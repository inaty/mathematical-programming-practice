# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from math_opt.utils import plot_map

# %% [markdown]
# ## Config

# %%
n_store = 20  # 店舗数
pos_warehouse = (0.5, 0.5)  # 倉庫の場所
store_pos_range = [(0, 0), (1, 1)]  # 店舗の存在可能範囲
stock_range = (5, 15)  # 店舗に必要な荷量範囲

n_truck = 2  # トラックの台数
truck_capacity = 100  # トラックの積載容量

# %%
np.random.seed(427)

# %%
pos_stores = np.random.rand(n_store, 2)
stocks = np.random.randint(*stock_range, size=n_store)
stores_info = {f'store_{i}': {'pos': pos, 'stock': stock} for i, (pos, stock) in enumerate(zip(pos_stores, stocks), start=1)}

# %%
plot_map(pos_warehouse, stores_info);
